# %% [markdown]
# ATP mechanism Implemenataion

# %%
# !git clone https://github.com/Lonelypheonix/ATP-Implementation.git
# Out:
# Cloning into 'ATP-Implementation'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 70 (delta 14), reused 54 (delta 14), pack-reused 0
# Receiving objects: 100% (70/70), 26.06 MiB | 18.38 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Updating files: 100% (51/51), done.

# %%
# %cd /content/ATP-Implementation/Code/
# Out:
# /content/ATP-Implementation/Code

# %%
# %run ATP.py
# Out:
# epsilon :  0.01 1000 / 3162 done.
# time: 10 : 33 : 50
# epsilon :  0.01 2000 / 3162 done.
# time: 10 : 33 : 57
# epsilon :  0.01 3000 / 3162 done.
# time: 10 : 34 : 2
# errors_NE k= 1 epsilon =  0.01 done. 9.988608289145471 px errors [[0.03956771 0.10620501 0.23905643 0.30500964 0.36189384]]
# time: 10 : 34 : 4
# epsilon :  0.05 1000 / 3162 done.
# time: 10 : 34 : 10
# epsilon :  0.05 2000 / 3162 done.
# time: 10 : 34 : 17
# epsilon :  0.05 3000 / 3162 done.
# time: 10 : 34 : 22
# errors_NE k= 1 epsilon =  0.05 done. 9.880752889519426 px errors [[0.04177359 0.10805059 0.23770594 0.31250075 0.36590125]]
# time: 10 : 34 : 23
# epsilon :  0.1 1000 / 3162 done.
# time: 10 : 34 : 30
# epsilon :  0.1 2000 / 3162 done.
# time: 10 : 34 : 36
# epsilon :  0.1 3000 / 3162 done.
# time: 10 : 34 : 42
# errors_NE k= 1 epsilon =  0.1 done. 10.025364955142528 px errors [[0.03572069 0.09969843 0.23328326 0.3044385  0.35605592]]
# time: 10 : 34 : 43
# epsilon :  0.5 1000 / 3162 done.
# ...

# %%
# %run ATP.py
# Out:
# epsilon :  0.01 1000 / 2794 done.
# time: 10 : 51 : 20
# epsilon :  0.01 2000 / 2794 done.
# time: 10 : 51 : 26
# errors_NE k= 1 epsilon =  0.01 done. 4.366575576975385 px errors [[0.0717051  0.19042975 0.37206088 0.51262271 0.6109269 ]]
# time: 10 : 51 : 31
# epsilon :  0.05 1000 / 2794 done.
# time: 10 : 51 : 37
# epsilon :  0.05 2000 / 2794 done.
# time: 10 : 51 : 43
# errors_NE k= 1 epsilon =  0.05 done. 4.335968915944302 px errors [[0.07518662 0.19014555 0.37574565 0.51763643 0.61052212]]
# time: 10 : 51 : 49
# epsilon :  0.1 1000 / 2794 done.
# time: 10 : 51 : 54
# epsilon :  0.1 2000 / 2794 done.
# time: 10 : 52 : 1
# errors_NE k= 1 epsilon =  0.1 done. 4.2700615143048966 px errors [[0.07007959 0.19519975 0.3803891  0.51407438 0.61800414]]
# time: 10 : 52 : 6
# epsilon :  0.5 1000 / 2794 done.
# time: 10 : 52 : 12
# epsilon :  0.5 2000 / 2794 done.
# time: 10 : 52 : 18
# ...
